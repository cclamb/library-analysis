# %%
from elftools.elf.elffile import ELFFile
from elftools.elf.relocation import RelocationSection
from elftools.elf.sections import SymbolTableSection

f = open('data/sample_exe64.elf', 'rb')

elf_file = ELFFile(f)

dwarf_info =  elf_file.get_dwarf_info()


def process_relocations(section):
    print '\t-> relocation section %s' % section.name
    print '\t\t%s section with %s relocation(s)' % (section.name, section.num_relocations())
    for relocation in section.iter_relocations():
        print '\t\tRelocation (%s)' % 'RELA' if relocation.is_RELA() else 'REL'
        print '\t\toffset = %s' % relocation['r_offset']

def process_symbol_table(section):
    header = section.header
    print '\t-> symbol table %s' % section.name
    print '\t\tSection name: %s, type: %s' % (header['sh_name'], header['sh_type'])
    print '\t\tIt is a symbol section with %s symbols' % section.num_symbols()
    for symbol in section.iter_symbols():
        print '\t\t\tname: %s entry type: %s' % (symbol.name, symbol.entry)

        
print 'Sections...'
print 'Looks like we have %s' % elf_file['e_shnum']
for section in elf_file.iter_sections():
    if section.name == '.rela.dyn':
        process_relocations(section)
    if section.name == '.symtab':
        process_symbol_table(section)
    else:
        print '\tname=%s' % section.name

print 'Compilation Units...'
for CU in dwarf_info.iter_CUs():
    print 'DIR on CU: '
    print 'Found a compile unit at offset %s, length %s' % (CU.cu_offset, CU['unit_length'])
    top_DIE = CU.get_top_DIE()
    print '\tTop DIE with tag=%s' % top_DIE.tag
    print '\tname=%s' % top_DIE.get_full_path()
    print '\taddress_size is %s' % CU['address_size']
    
print type(elf_file.elfclass)
# Out:
# Sections...
# Looks like we have 42
# 	name=
# 	name=.interp
# 	name=.note.ABI-tag
# 	name=.note.SuSE
# 	name=.note.gnu.build-id
# 	name=.hash
# 	name=.gnu.hash
# 	name=.dynsym
# 	name=.dynstr
# 	name=.gnu.version
# 	name=.gnu.version_r
# 	-> relocation section .rela.dyn
# 		.rela.dyn section with 1 relocation(s)
# 		Relocation (RELA)
# 		offset = 6295520
# 	name=.rela.dyn
# 	name=.rela.plt
# 	name=.init
# 	name=.plt
# 	name=.text
# 	name=.fini
# 	name=.rodata
# 	name=.eh_frame_hdr
# 	name=.eh_frame
# 	name=.ctors
# 	name=.dtors
# 	name=.jcr
# 	name=.dynamic
# 	name=.got
# 	name=.got.plt
# 	name=.data
# 	name=.bss
# 	name=.comment.SUSE.OPTs
# 	name=.comment
# 	name=.debug_aranges
# 	name=.debug_pubnames
# 	name=.debug_info
# 	name=.debug_abbrev
# 	name=.debug_line
# 	name=.debug_frame
# 	name=.debug_str
# 	name=.debug_loc
# 	name=.debug_ranges
# 	name=.shstrtab
# 	-> symbol table .symtab
# 		Section name: 1, type: SHT_SYMTAB
# 		It is a symbol section with 80 symbols
# ...
